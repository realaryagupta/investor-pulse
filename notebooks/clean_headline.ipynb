# %%
import pandas as pd

# %%
data = pd.read_csv("/content/cleaned_headlines.csv")

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
data.head()
# Out:
#    Unnamed: 0        date company  \
# 0           0  2025-05-29   GOOGL
# 1           1  2025-05-29    TSLA
# 2           2  2025-05-29    AAPL
# 3           6  2025-05-29    AAPL
# 4           7  2025-05-29    MSFT
#
#                                     cleaned_headline
# 0  bill nygrens strategic moves constellation bra...
# 1  market today nvidia nvda leads ai surge amid s...
# 2  asx market open trump tariff appeal ruling bum...
# 3  sonder holdings inc receives notification of d...
# 4  netapp reports record results for fourth quart...

# %%
headlines = data['cleaned_headline'].tolist()

# %%
import torch

inputs = tokenizer(headlines, padding=True, truncation=True, return_tensors="pt")
with torch.no_grad():
    outputs = model(**inputs)

# %%
import torch.nn.functional as F
predictions = F.softmax(outputs.logits, dim=-1)

# %%
labels = ['positive', 'negative', 'neutral']
predicted_classes = predictions.argmax(axis=1)
data['sentiment'] = [labels[i] for i in predicted_classes]
data['sentiment_score'] = predictions.max(axis=1).values

# %%
data
# Out:
#      Unnamed: 0        date company  \
# 0             0  2025-05-29   GOOGL
# 1             1  2025-05-29    TSLA
# 2             2  2025-05-29    AAPL
# 3             6  2025-05-29    AAPL
# 4             7  2025-05-29    MSFT
# ..          ...         ...     ...
# 321         389  2025-05-27    TSLA
# 322         390  2025-05-27   GOOGL
# 323         391  2025-05-27    AAPL
# 324         392  2025-05-27    MSFT
# 325         393  2025-05-27    TSLA
#
#                                       cleaned_headline sentiment  \
# 0    bill nygrens strategic moves constellation bra...   neutral
# 1    market today nvidia nvda leads ai surge amid s...  positive
# 2    asx market open trump tariff appeal ruling bum...   neutral
# 3    sonder holdings inc receives notification of d...  negative
# 4    netapp reports record results for fourth quart...  positive
# ..                                                 ...       ...
# 321  tesla struggles in europe as sales plunge 49 y...  negative
# 322  youtube ceo neal mohan says the streaming gian...  negative
# 323  stock market today markets rally as trump dela...  negative
# 324  stock market today markets rally as trump dela...  negative
# 325  stock market today markets rally as trump dela...  negative
#
#      sentiment_score
# 0           0.784569
# 1           0.926326
# 2           0.644258
# 3           0.947585
# 4           0.922512
# ..               ...
# 321         0.966155
# 322         0.822908
# 323         0.774963
# 324         0.774963
# 325         0.774963
#
# [326 rows x 6 columns]

# %%
data.drop('Unnamed: 0', axis =1, inplace = True)

# %%
data.to_csv("final_clean_headlines.csv")
